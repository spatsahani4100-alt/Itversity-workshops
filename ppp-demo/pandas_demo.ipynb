# %%
import pandas as pd

# %%
car_sales = pd.read_csv('car_sales_2024.csv')

# %%
car_sales.shape
# Out:
# (5000, 15)

# %%
car_sales.head()
# Out:
#         sale_id   sale_date customer_id car_make car_model  car_year category  \
# 0  SALE20244500  2024-01-01   CUST14500    Honda    Accord      2023    Sedan
# 1  SALE20241760  2024-01-01   CUST11760      BMW  3 Series      2024   Luxury
# 2  SALE20241772  2024-01-01   CUST11772    Mazda      CX-5      2024      SUV
# 3  SALE20241776  2024-01-01   CUST11776   Nissan     Rogue      2023      SUV
# 4  SALE20242044  2024-01-01   CUST12044     Ford     F-150      2024    Truck
#
#    color  mileage  sale_price payment_method        dealership  \
# 0  Black       16    29518.87          Lease     Westside Auto
# 1  Black       35    47624.88        Finance  North Point Cars
# 2  White        8    31947.14        Finance   Downtown Motors
# 3  Brown       10    30553.60          Lease   Downtown Motors
# 4  White       23    46295.44           Cash   Downtown Motors
#
#       salesperson state  commission
# 0  David Anderson    FL      850.20
# 1    Mary Jackson    IL     1012.44
# 2     Emily Davis    PA     1079.20
# 3   Sarah Johnson    PA     1296.27
# 4    James Thomas    NC     1958.91

# %%
# Get the sales for a given state
state = input("Enter the state: ")
state_sales = car_sales.query("state == @state")

# %%
state_sales.shape
# Out:
# (0, 15)

# %%
state_sales.head()
# Out:
# Empty DataFrame
# Columns: [sale_id, sale_date, customer_id, car_make, car_model, car_year, category, color, mileage, sale_price, payment_method, dealership, salesperson, state, commission]
# Index: []

# %%
# Get sales by state
state_sales = car_sales.groupby('state'). \
    agg(total_sales=('sale_price', 'sum'), \
        sale_count=('sale_price', 'count'))

# %%
state_sales.shape
# Out:
# (10, 2)

# %%
state_sales.head()
# Out:
#        total_sales  sale_count
# state
# CA     18727709.11         509
# FL     20220854.18         538
# GA     18921434.95         505
# IL     20205300.48         512
# MI     18264746.87         498

# %%
state_sales. \
    reset_index(). \
    sort_values('total_sales', ascending=False)
# Out:
#   state  total_sales  sale_count
# 1    FL  20220854.18         538
# 3    IL  20205300.48         512
# 7    OH  19920681.73         524
# 6    NY  19062197.61         508
# 2    GA  18921434.95         505
# 0    CA  18727709.11         509
# 9    TX  18309337.33         489
# 4    MI  18264746.87         498
# 8    PA  17866692.35         480
# 5    NC  16101036.37         437
